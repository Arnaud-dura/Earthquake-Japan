# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.image as img

# %%
data_pop = pd.read_csv('Japan_population_data.csv',sep=";")
data_seisme = pd.read_csv('Japan earthquakes 2001 - 2018.csv',sep=";")
data_seisme
# Out:
#                           time  latitude  longitude   depth  mag  \
# 0     2009-06-05T03:36:53.750Z   43.6290   140.9880  211.90  4.5
# 1     2016-12-08T10:58:56.100Z   43.5842   140.7165   21.67  4.6
# 2     2002-05-01T05:56:26.280Z   43.1520   140.0790  177.90  4.6
# 3     2010-12-01T21:44:06.680Z   43.0330   141.4090   35.00  4.5
# 4     2017-07-01T14:45:53.440Z   42.8140   141.9263   36.73  5.3
# ...                        ...       ...        ...     ...  ...
# 3979  2001-02-26T02:22:51.200Z   25.0090   127.1330   33.00  4.9
# 3980  2004-08-24T14:53:48.560Z   25.0080   128.3030   35.00  4.5
# 3981  2016-05-12T22:28:20.150Z   31.0000   129.1689   10.00  4.5
# 3982  2009-12-28T04:13:28.170Z   28.0000   128.4240   91.50  4.6
# 3983  2008-04-18T05:58:36.480Z   26.0000   128.4060   28.70  5.1
#
#                        updated  magNst  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0     2014-11-07T01:39:06.920Z     5.0         NaN         NaN         NaN
# ...

# %%
lat_pop = data_pop["Latitude"][1:48]
long_pop = data_pop["Longitude"][1:48]
villes = data_pop["capital"][1:48]
lat_seisme = data_seisme["latitude"]
long_seisme = data_seisme["longitude"]

# %%
plt.scatter(lat_seisme,long_seisme, color="grey")
plt.scatter(lat_pop,long_pop,color="green")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(long_seisme,lat_seisme, color="grey")
plt.scatter(long_pop,lat_pop,color="green")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
